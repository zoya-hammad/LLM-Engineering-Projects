# %% [markdown]
# ## Predicting Product Prices
#
# Selecting a model and evaluating the quantized base model against the task.

# %%
# pip installs - ignore the error message!

# !pip install -q datasets requests torch peft bitsandbytes transformers trl accelerate sentencepiece tiktoken matplotlib

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, set_seed
from peft import LoraConfig, PeftModel
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Tokenizers

LLAMA_3_1 = "meta-llama/Meta-Llama-3.1-8B"
QWEN_2_5 = "Qwen/Qwen2.5-7B"
GEMMA_2 = "google/gemma-2-9b"
PHI_3 = "microsoft/Phi-3-medium-4k-instruct"

# Constants

BASE_MODEL = LLAMA_3_1
HF_USER = "zoya-hammadk"
DATASET_NAME = f"{HF_USER}/pricer-data"
MAX_SEQUENCE_LENGTH = 182
QUANT_4_BIT = True

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %matplotlib inline

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
def investigate_tokenizer(model_name):
  print("Investigating tokenizer for", model_name)
  tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
  for number in [0, 1, 10, 100, 999, 1000]:
    tokens = tokenizer.encode(str(number), add_special_tokens=False)
    print(f"The tokens for {number}: {tokens}")

# %%
investigate_tokenizer(LLAMA_3_1)
# Out:
# Investigating tokenizer for meta-llama/Meta-Llama-3.1-8B
# The tokens for 0: [15]
# The tokens for 1: [16]
# The tokens for 10: [605]
# The tokens for 100: [1041]
# The tokens for 999: [5500]
# The tokens for 1000: [1041, 15]

# %%
investigate_tokenizer(QWEN_2_5)
# Out:
# Investigating tokenizer for Qwen/Qwen2.5-7B
# tokenizer_config.json:   0%|          | 0.00/7.23k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# The tokens for 0: [15]
# The tokens for 1: [16]
# The tokens for 10: [16, 15]
# The tokens for 100: [16, 15, 15]
# The tokens for 999: [24, 24, 24]
# The tokens for 1000: [16, 15, 15, 15]

# %%
investigate_tokenizer(GEMMA_2)
# Out:
# Investigating tokenizer for google/gemma-2-9b
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# The tokens for 0: [235276]
# The tokens for 1: [235274]
# The tokens for 10: [235274, 235276]
# The tokens for 100: [235274, 235276, 235276]
# The tokens for 999: [235315, 235315, 235315]
# The tokens for 1000: [235274, 235276, 235276, 235276]

# %%
investigate_tokenizer(PHI_3)
# Out:
# Investigating tokenizer for microsoft/Phi-3-medium-4k-instruct
# The tokens for 0: [29871, 29900]
# The tokens for 1: [29871, 29896]
# The tokens for 10: [29871, 29896, 29900]
# The tokens for 100: [29871, 29896, 29900, 29900]
# The tokens for 999: [29871, 29929, 29929, 29929]
# The tokens for 1000: [29871, 29896, 29900, 29900, 29900]

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nAXE HEAVEN Stranger Things Eddie's Guitar Mini Guitar Model\nIT'S TIME. Officially Licensed Stranger Things Eddie's Guitar B.C. Rich NJ Warlock Mini Guitar Model - 100% HANDCRAFTED with an amazing crackle finish just as seen in the NETFLIX Series. This collectible miniature guitar replica was hand-crafted to honor Eddie's Warlock guitar as seen in the NETFLIX Stranger Things series (and Official Trailer below). This miniature has captured all of the distinct features that the real guitar B.C. Rich Guitar has. * INCLUDES THE LIMITED EDITION STRANGER THINGS COLLECTORS SLEEVE\\nINCLUDES THE LIMITED EDITION STRANGER THINGS COLLECTORS SLEEVE\\nIndividually Handcrafted with the highest attention to detail\\n\n\nPrice is $",
#  'price': 32.7}

# %% [markdown]
# ### Prepare our Base Llama Model for evaluation
#
# Load our base model with 4 bit quantization and try out 1 example

# %%
## pick the right quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

print(f"Memory footprint: {base_model.get_memory_footprint() / 1e9:.1f} GB")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Memory footprint: 5.6 GB

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','').replace('$','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = base_model.generate(inputs, max_new_tokens=4, attention_mask=attention_mask, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
model_predict(test[0]['text'])
# Out:
# 25.0

# %% [markdown]
# ### Evaluation!
#
# Trying out our base Llama 3.1 model against the Test dataset

# %%
import datetime

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)

        safe_title = self.title.replace(" ", "_").lower()
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"{safe_title}_{timestamp}.png"
        plt.savefig(filename, dpi=300)

        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"

        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        model_name = self.predictor.__name__

        log_entry = (
        f"===== {self.title} =====\n"
        f"Timestamp: {timestamp}\n"
        f"Model: {model_name}\n"
        f"Results: {title}\n\n"
        )

        with open("tester_log.txt", "a") as f:
          f.write(log_entry)

        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(model_predict, test)
# Out:
# 1: Guess: $25.00 Truth: $32.70 Error: $7.70 SLE: 0.07 Item: AXE HEAVEN Stranger ...
# 2: Guess: $1.00 Truth: $213.94 Error: $212.94 SLE: 21.88 Item: Southbend Range Natu...
# 3: Guess: $25.00 Truth: $79.99 Error: $54.99 SLE: 1.29 Item: SUNY Party Lights DJ...
# 4: Guess: $25.99 Truth: $18.99 Error: $7.00 SLE: 0.09 Item: 113PCS Birthday Part...
# 5: Guess: $25.00 Truth: $44.95 Error: $19.95 SLE: 0.32 Item: Artist Unknown A- B ...
# 6: Guess: $25.00 Truth: $84.99 Error: $59.99 SLE: 1.43 Item: PINK Child’s Practic...
# 7: Guess: $1,800.00 Truth: $592.95 Error: $1,207.05 SLE: 1.23 Item: PENNZONI 4ft Drum Sh...
# 8: Guess: $19.99 Truth: $325.01 Error: $305.02 SLE: 7.52 Item: LEGO Bionicle Umarak...
# 9: Guess: $25.00 Truth: $90.99 Error: $65.99 SLE: 1.60 Item: (Red) - Hape E3153 T...
# 10: Guess: $19.99 Truth: $52.39 Error: $32.40 SLE: 0.87 Item: LEGO DUPLO My Town B...
# 11: Guess: $25.00 Truth: $202.47 Error: $177.47 SLE: 4.23 Item: Aquamarine Fate/Gran...
# 12: Guess: $25.00 Truth: $161.58 Error: $136.58 SLE: 3.36 Item: Mytheos Kakegurui xx...
# 13: Guess: $7.50 Truth: $25.95 Error: $18.45 SLE: 1.33 Item: Rotosond Stainless S...
# 14: Guess: $7.99 Truth: $44.05 Error: $36.06 SLE: 2.60 Item: DKKY Upgrade Shock T...
# 15: Guess: $19.99 Truth: $69.99 Error: $50.00 SLE: 1.48 Item: Ranch Concert Ukulel...
# 16: Guess: $25.00 Truth: $99.95 Error: $74.95 SLE: 1.84 Item: BOYA Large-Diaphragm...
# 17: Guess: $25.00 Truth: $89.69 Error: $64.69 SLE: 1.56 Item: TOYSLY Off-Road Pick...
# 18: Guess: $25.00 Truth: $127.99 Error: $102.99 SLE: 2.57 Item: Medicom The Return o...
# 19: Guess: $7.50 Truth: $34.94 Error: $27.44 SLE: 2.08 Item: Axe Heaven FS-013 Fe...
# 20: Guess: $7.00 Truth: $34.99 Error: $27.99 SLE: 2.26 Item: Grover CP68 Leather ...
# 21: Guess: $25.99 Truth: $72.99 Error: $47.00 SLE: 1.02 Item: Costzon 3 in 1 Kids ...
# 165: Guess: $25.00 Truth: $99.99 Error: $74.99 SLE: 1.84 Item: Replogle Reso Tradit...
# 166: Guess: $1.00 Truth: $32.50 Error: $31.50 SLE: 7.94 Item: Technica Brand Compa...
# 167: Guess: $7.99 Truth: $54.99 Error: $47.00 SLE: 3.35 Item: RCMYou RC Stainless ...
# 168: Guess: $7.99 Truth: $6.22 Error: $1.77 SLE: 0.05 Item: BQLZR Guitar Potenti...
# 169: Guess: $19.95 Truth: $49.55 Error: $29.60 SLE: 0.78 Item: Vox VFS2A Dual Guita...
# 170: Guess: $7.99 Truth: $8.99 Error: $1.00 SLE: 0.01 Item: NUOMI Flannel Cloth ...
# 171: Guess: $25.00 Truth: $92.16 Error: $67.16 SLE: 1.63 Item: Max Factory Genshin ...
# 172: Guess: $25.00 Truth: $139.99 Error: $114.99 SLE: 2.86 Item: J Reynolds JR14PK Ac...
# 173: Guess: $19.99 Truth: $77.98 Error: $57.99 SLE: 1.76 Item: LEGO City Great Vehi...
# 174: Guess: $25.00 Truth: $119.95 Error: $94.95 SLE: 2.36 Item: Diamond Select Toys ...
# 175: Guess: $299.00 Truth: $379.95 Error: $80.95 SLE: 0.06 Item: Fishman Fluence Greg...
# 176: Guess: $19.95 Truth: $64.99 Error: $45.04 SLE: 1.32 Item: Merchants & Marauder...
# 177: Guess: $89.99 Truth: $99.00 Error: $9.01 SLE: 0.01 Item: Ryze Tech Tello - Mi...
# 178: Guess: $1.00 Truth: $37.50 Error: $36.50 SLE: 8.75 Item: Jigsaw Puzzles Switz...
# 179: Guess: $25.00 Truth: $99.95 Error: $74.95 SLE: 1.84 Item: Avedis Zildjian Comp...
# 180: Guess: $19.99 Truth: $25.59 Error: $5.60 SLE: 0.06 Item: Sueseip Kids Smart W...
# 181: Guess: $25.00 Truth: $159.00 Error: $134.00 SLE: 3.30 Item: EMG ACS Acoustic Gui...
# 182: Guess: $25.00 Truth: $165.10 Error: $140.10 SLE: 3.44 Item: Hipshot Tone-a-Matic...
# 183: Guess: $25.00 Truth: $51.09 Error: $26.09 SLE: 0.48 Item: Sunny toys 28 Angel ...
# 184: Guess: $299.00 Truth: $291.99 Error: $7.01 SLE: 0.00 Item: Btuty Eb E-flat Alto...
# 185: Guess: $25.00 Truth: $13.99 Error: $11.01 SLE: 0.30 Item: Luluo Santa Claus Ch...
# 186: Guess: $7.00 Truth: $139.95 Error: $132.95 SLE: 8.23 Item: OEM Samsung Dryer Li...
# 187: Guess: $1.00 Truth: $9.99 Error: $8.99 SLE: 2.90 Item: Funnlot Hanukkah Gam...
# 188: Guess: $19.99 Truth: $9.99 Error: $10.00 SLE: 0.42 Item: Coola Christmas Craf...
# 189: Guess: $299.00 Truth: $699.99 Error: $400.99 SLE: 0.72 Item: Ibanez AG95QA AG Art...
# 190: Guess: $19.99 Truth: $139.41 Error: $119.42 SLE: 3.61 Item: DW Hobby 3D Flying A...
# 191: Guess: $89.99 Truth: $132.95 Error: $42.96 SLE: 0.15 Item: STEAMFORGED Godtear ...
# 192: Guess: $7.99 Truth: $8.90 Error: $0.91 SLE: 0.01 Item: Interal Shop Guitar ...
# 193: Guess: $1.00 Truth: $69.41 Error: $68.41 SLE: 12.68 Item: Electrolux Door Hand...
# 194: Guess: $19.99 Truth: $49.95 Error: $29.96 SLE: 0.79 Item: Maisto R/C 27Mhz Roc...
# 195: Guess: $7.99 Truth: $20.99 Error: $13.00 SLE: 0.80 Item: Odowalker Pack of 4 ...
# 196: Guess: $19.99 Truth: $314.95 Error: $294.96 SLE: 7.35 Item: Pokemon TCG XY Evolu...
# 197: Guess: $25.00 Truth: $27.99 Error: $2.99 SLE: 0.01 Item: Transformer Toy Defo...
# 198: Guess: $25.00 Truth: $54.99 Error: $29.99 SLE: 0.59 Item: PlanToys Van Walker,...
# 199: Guess: $19.99 Truth: $27.99 Error: $8.00 SLE: 0.10 Item: Living Nature Brown ...
# 200: Guess: $19.99 Truth: $16.99 Error: $3.00 SLE: 0.02 Item: Silence Razer Mini S...
# 201: Guess: $89.99 Truth: $119.95 Error: $29.96 SLE: 0.08 Item: LEGO NINJAGO Fire St...
# 202: Guess: $25.00 Truth: $110.67 Error: $85.67 SLE: 2.12 Item: Saint Seiya Myth Clo...
# 203: Guess: $25.00 Truth: $57.99 Error: $32.99 SLE: 0.67 Item: Funko POP Games Fall...
# 204: Guess: $25.00 Truth: $169.00 Error: $144.00 SLE: 3.53 Item: Kala KA-CE Satin Mah...
# 205: Guess: $25.00 Truth: $108.15 Error: $83.15 SLE: 2.06 Item: Bandaï Saint Seiya S...
# 206: Guess: $19.99 Truth: $30.99 Error: $11.00 SLE: 0.18 Item: LESHITIAN Kids Lapto...
# 207: Guess: $299.99 Truth: $399.99 Error: $100.00 SLE: 0.08 Item: Causeair Big Inflata...
# 208: Guess: $19.99 Truth: $128.89 Error: $108.90 SLE: 3.32 Item: MAYS 3D Metal Puzzle...
# 209: Guess: $25.00 Truth: $219.95 Error: $194.95 SLE: 4.58 Item: DisplayGifts Electri...
# 210: Guess: $25.00 Truth: $42.98 Error: $17.98 SLE: 0.28 Item: QT RC Airplane, 2 Ch...
# 211: Guess: $25.00 Truth: $37.76 Error: $12.76 SLE: 0.16 Item: Traxxas 5374X BRUSHL...
# 212: Guess: $25.00 Truth: $98.99 Error: $73.99 SLE: 1.81 Item: Kotobukiya ARTFX+ St...
# 213: Guess: $299.99 Truth: $189.95 Error: $110.04 SLE: 0.21 Item: Aosom 12V Ride On To...
# 214: Guess: $1.00 Truth: $5.48 Error: $4.48 SLE: 1.38 Item: Violin Bow Clip Kit ...
# 215: Guess: $25.00 Truth: $75.00 Error: $50.00 SLE: 1.15 Item: Funko POP Movies Boo...
# 216: Guess: $25.00 Truth: $34.99 Error: $9.99 SLE: 0.11 Item: Seasons Viking Princ...
# 217: Guess: $7.50 Truth: $16.99 Error: $9.49 SLE: 0.56 Item: Ernie Ball 2566 Alum...
# 218: Guess: $7.99 Truth: $19.99 Error: $12.00 SLE: 0.72 Item: Egg Holder for Refri...
# 219: Guess: $299.00 Truth: $129.99 Error: $169.01 SLE: 0.69 Item: Zoom MS-50G MultiSto...
# 220: Guess: $25.00 Truth: $254.35 Error: $229.35 SLE: 5.22 Item: SOUTHBEND RANGE Hi L...
# 221: Guess: $19.99 Truth: $37.99 Error: $18.00 SLE: 0.38 Item: 12 pack Acoustic Pan...
# 222: Guess: $299.00 Truth: $219.99 Error: $79.01 SLE: 0.09 Item: Nektar Pacer - USB M...
# 223: Guess: $59.99 Truth: $79.98 Error: $19.99 SLE: 0.08 Item: Steel Tongue Drum, H...
# 224: Guess: $25.00 Truth: $51.95 Error: $26.95 SLE: 0.51 Item: Protect'em Covers Pa...
# 225: Guess: $25.00 Truth: $94.66 Error: $69.66 SLE: 1.70 Item: Beast Kingdom The Da...
# 226: Guess: $7.99 Truth: $16.99 Error: $9.00 SLE: 0.48 Item: Ant Mag Guitar Hange...
# 227: Guess: $19.99 Truth: $48.95 Error: $28.96 SLE: 0.75 Item: Diamond Select Toys ...
# 228: Guess: $7.99 Truth: $62.99 Error: $55.00 SLE: 3.85 Item: Shopkins Food Themed...
# 229: Guess: $19.99 Truth: $24.95 Error: $4.96 SLE: 0.04 Item: Wettarn 10 Set Gradu...
# 230: Guess: $19.99 Truth: $63.98 Error: $43.99 SLE: 1.28 Item: Spider-Man Marvel Th...
# 231: Guess: $19.99 Truth: $84.95 Error: $64.96 SLE: 1.99 Item: Hot Wheels Team Hot ...
# 232: Guess: $19.99 Truth: $39.99 Error: $20.00 SLE: 0.45 Item: DNYSYSJ Mini Portabl...
# 233: Guess: $25.00 Truth: $42.99 Error: $17.99 SLE: 0.28 Item: Disco Mirror Ball Si...
# 234: Guess: $7.50 Truth: $6.00 Error: $1.50 SLE: 0.04 Item: Djeco Stickers, Knig...
# 235: Guess: $7.99 Truth: $28.89 Error: $20.90 SLE: 1.44 Item: PK Power AC/DC Adapt...
# 236: Guess: $7.00 Truth: $19.99 Error: $12.99 SLE: 0.93 Item: Supplying Demand Clo...
# 237: Guess: $19.99 Truth: $75.00 Error: $55.01 SLE: 1.66 Item: Nerf N-Strike Maveri...
# 238: Guess: $19.99 Truth: $79.99 Error: $60.00 SLE: 1.82 Item: SpeedArmis Giant Woo...
# 239: Guess: $19.99 Truth: $11.95 Error: $8.04 SLE: 0.23 Item: BOHS Montessori 1-10...
# 240: Guess: $25.00 Truth: $46.39 Error: $21.39 SLE: 0.36 Item: Papillon dog figure ...
# 241: Guess: $7.00 Truth: $28.99 Error: $21.99 SLE: 1.75 Item: Supplying Demand Ele...
# 242: Guess: $25.99 Truth: $35.96 Error: $9.97 SLE: 0.10 Item: Eenbei Talking Angel...
# 243: Guess: $25.00 Truth: $56.40 Error: $31.40 SLE: 0.63 Item: Springbok Coca-Cola ...
# 244: Guess: $299.00 Truth: $99.00 Error: $200.00 SLE: 1.21 Item: Saramonic 2.4GHz Dua...
# 245: Guess: $25.00 Truth: $82.88 Error: $57.88 SLE: 1.37 Item: Barbie as Scarlett O...
# 246: Guess: $25.00 Truth: $84.88 Error: $59.88 SLE: 1.43 Item: DC Collectibles Batm...
# 247: Guess: $25.00 Truth: $53.00 Error: $28.00 SLE: 0.53 Item: 3rd Eye, or Pineal C...
# 248: Guess: $7.99 Truth: $12.13 Error: $4.14 SLE: 0.14 Item: Yosoo Health Gear Sh...
# 249: Guess: $110.00 Truth: $114.99 Error: $4.99 SLE: 0.00 Item: LEGO Creator Expert ...
# 250: Guess: $7.50 Truth: $51.29 Error: $43.79 SLE: 3.30 Item: Hohner Blues Harp Ha...
